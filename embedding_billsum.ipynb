# %%
# !pip install tiktoken

# %% [markdown]
# Model references
# ================
# https://learn.microsoft.com/en-US/azure/ai-services/openai/reference
#
# Tutorial references
# ===================
# https://learn.microsoft.com/en-us/azure/ai-services/openai/tutorials/embeddings?tabs=command-line

# %%
import openai
import os
import re
import requests
# import sys
# from num2words import num2words
import os
import pandas as pd
# import numpy as np
from openai.embeddings_utils import get_embedding, cosine_similarity
import tiktoken

API_KEY = os.getenv("AZURE_OPENAI_API_KEY") 
RESOURCE_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT") 

openai.api_type = "azure"
openai.api_key = API_KEY
openai.api_base = RESOURCE_ENDPOINT
openai.api_version = "2023-05-15"

url = openai.api_base + "/openai/deployments?api-version=2023-03-15-preview" 

r = requests.get(url, headers={"api-key": API_KEY})

print(r.text)
# Out:
# {
#   "data": [
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "code-davinci-002",
#       "owner": "organization-owner",
#       "id": "codex1",
#       "status": "succeeded",
#       "created_at": 1676872153,
#       "updated_at": 1676872153,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "text-davinci-003",
#       "owner": "organization-owner",
#       "id": "test-davinci-003",
#       "status": "succeeded",
#       "created_at": 1676949323,
#       "updated_at": 1676949323,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "text-similarity-curie-001",
#       "owner": "organization-owner",
#       "id": "text-similarity-curie-001",
#       "status": "succeeded",
#       "created_at": 1676949568,
#       "updated_at": 1676949568,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "text-davinci-002",
#       "owner": "organization-owner",
#       "id": "text-davinci-002",
#       "status": "succeeded",
#       "created_at": 1676954637,
#       "updated_at": 1676954637,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "gpt-35-turbo",
#       "owner": "organization-owner",
#       "id": "glovebox-chat",
#       "status": "succeeded",
#       "created_at": 1681369060,
#       "updated_at": 1681369060,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "text-embedding-ada-002",
#       "owner": "organization-owner",
#       "id": "text-embedding-ada-002",
#       "status": "succeeded",
#       "created_at": 1692771912,
#       "updated_at": 1692771912,
#       "object": "deployment"
#     }
#   ],
#   "object": "list"
# }

# %%
df = pd.read_csv("./data/bill_sum_data.csv") # example: df = pd.read_csv("./data/bill_sum_data.csv")df
df
# Out:
#     Unnamed: 0     bill_id                                               text  \
# 0            0    110_hr37  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 1            1  112_hr2873  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 2            2   109_s2408  SECTION 1. RELEASE OF DOCUMENTS CAPTURED IN IR...
# 3            3   108_s1899  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 4            4   107_s1531  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 5            5  107_hr4541  SECTION 1. RELIQUIDATION OF CERTAIN ENTRIES PR...
# 6            6   111_s1495  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 7            7   111_s3885  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 8            8  113_hr1796  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 9            9  103_hr1987  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 10          10  103_hr1677  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 11          11   111_s3149  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 12          12  110_hr1007  SECTION 1. FINDINGS.\n\n    The Congress finds...
# 13          13  113_hr3137  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 14          14  115_hr1634  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 15          15  103_hr1815  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 16          16   113_s1773  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 17          17  106_hr5585  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 18          18  114_hr2499  SECTION 1. SHORT TITLE.\n    This Act may be c...
# 19          19  111_hr3141  SECTION 1. SHORT TITLE.\n\n    This Act may be...
#
#                                               summary  \
# 0   National Science Education Tax Incentive for B...
# 1   Small Business Expansion and Hiring Act of 201...
# 2   Requires the Director of National Intelligence...
# 3   National Cancer Act of 2003 - Amends the Publi...
# 4   Military Call-up Relief Act - Amends the Inter...
# 5   Requires the Customs Service to reliquidate ce...
# 6   Service Dogs for Veterans Act of 2009 - Direct...
# 7   Race to the Top Act of 2010 - Directs the Secr...
# 8   Troop Talent Act of 2013 - Directs the Secreta...
# 9   Taxpayer's Right to View Act of 1993 - Amends ...
# 10  Full-Service Schools Act - Establishes the Fed...
# 11  Wall Street Compensation Reform Act of 2010 - ...
# 12  Amends the Marine Mammal Protection Act of 197...
# 13  Freedom and Mobility in Consumer Banking Act -...
# 14  Education and Training for Health Act of 2017 ...
# 15  Recreational Hunting Safety and Preservation A...
# 16  Andrew Prior Act or Andrew's Law - Amends the ...
# 17  Directs the President, in coordination with de...
# 18  This measure has not been amended since it was...
# 19  Strengthening the Health Care Safety Net Act o...
#
#                                                 title  text_len  sum_len
# 0   To amend the Internal Revenue Code of 1986 to ...      8494      321
# 1   To amend the Internal Revenue Code of 1986 to ...      6522     1424
# 2   A bill to require the Director of National Int...      6154      463
# 3   A bill to improve data collection and dissemin...     19853     1400
# 4   A bill to amend the Internal Revenue Code of 1...      6273      278
# 5   To provide for reliquidation of entries premat...     11691      114
# 6   A bill to require the Secretary of Veterans Af...      5328      379
# 7   A bill to provide incentives for States and lo...     16668     1525
# 8                            Troop Talent Act of 2013     15352     2151
# 9                Taxpayer's Right to View Act of 1993      5633      894
# 10                           Full-Service Schools Act     12472     1107
# 11  A bill to amend the Internal Revenue Code of 1...     18226     1297
# 12  To amend the Marine Mammal Protection Act of 1...      5261      276
# 13       Freedom and Mobility in Consumer Banking Act     17690     2044
# 14      Education and Training for Health Act of 2017      9037      772
# 15  Recreational Hunting Safety and Preservation A...     13024      475
# 16                                       Andrew's Law      5149      613
# 17                    Energy Independence Act of 2000      8007      810
# 18              Veterans Entrepreneurship Act of 2015      7539     1421
# 19  To amend title XIX of the Social Security Act ...     18429      514

# %%
df_bills = df[['text', 'summary', 'title', 'text_len']]
df_bills
# Out:
#                                                  text  \
# 0   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 1   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 2   SECTION 1. RELEASE OF DOCUMENTS CAPTURED IN IR...
# 3   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 4   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 5   SECTION 1. RELIQUIDATION OF CERTAIN ENTRIES PR...
# 6   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 7   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 8   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 9   SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 10  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 11  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 12  SECTION 1. FINDINGS.\n\n    The Congress finds...
# 13  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 14  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 15  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 16  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 17  SECTION 1. SHORT TITLE.\n\n    This Act may be...
# 18  SECTION 1. SHORT TITLE.\n    This Act may be c...
# 19  SECTION 1. SHORT TITLE.\n\n    This Act may be...
#
#                                               summary  \
# 0   National Science Education Tax Incentive for B...
# 1   Small Business Expansion and Hiring Act of 201...
# 2   Requires the Director of National Intelligence...
# 3   National Cancer Act of 2003 - Amends the Publi...
# 4   Military Call-up Relief Act - Amends the Inter...
# 5   Requires the Customs Service to reliquidate ce...
# 6   Service Dogs for Veterans Act of 2009 - Direct...
# 7   Race to the Top Act of 2010 - Directs the Secr...
# 8   Troop Talent Act of 2013 - Directs the Secreta...
# 9   Taxpayer's Right to View Act of 1993 - Amends ...
# 10  Full-Service Schools Act - Establishes the Fed...
# 11  Wall Street Compensation Reform Act of 2010 - ...
# 12  Amends the Marine Mammal Protection Act of 197...
# 13  Freedom and Mobility in Consumer Banking Act -...
# 14  Education and Training for Health Act of 2017 ...
# 15  Recreational Hunting Safety and Preservation A...
# 16  Andrew Prior Act or Andrew's Law - Amends the ...
# 17  Directs the President, in coordination with de...
# 18  This measure has not been amended since it was...
# 19  Strengthening the Health Care Safety Net Act o...
#
#                                                 title  text_len
# 0   To amend the Internal Revenue Code of 1986 to ...      8494
# 1   To amend the Internal Revenue Code of 1986 to ...      6522
# 2   A bill to require the Director of National Int...      6154
# 3   A bill to improve data collection and dissemin...     19853
# 4   A bill to amend the Internal Revenue Code of 1...      6273
# 5   To provide for reliquidation of entries premat...     11691
# 6   A bill to require the Secretary of Veterans Af...      5328
# 7   A bill to provide incentives for States and lo...     16668
# 8                            Troop Talent Act of 2013     15352
# 9                Taxpayer's Right to View Act of 1993      5633
# 10                           Full-Service Schools Act     12472
# 11  A bill to amend the Internal Revenue Code of 1...     18226
# 12  To amend the Marine Mammal Protection Act of 1...      5261
# 13       Freedom and Mobility in Consumer Banking Act     17690
# 14      Education and Training for Health Act of 2017      9037
# 15  Recreational Hunting Safety and Preservation A...     13024
# 16                                       Andrew's Law      5149
# 17                    Energy Independence Act of 2000      8007
# 18              Veterans Entrepreneurship Act of 2015      7539
# 19  To amend title XIX of the Social Security Act ...     18429

# %%
# s is input text
def normalize_text(s, sep_token = " \n "):
    s = re.sub(r'\s+',  ' ', s).strip()
    s = re.sub(r". ,","",s)
    # remove all instances of multiple spaces
    s = s.replace("..",".")
    s = s.replace(". .",".")
    s = s.replace("\n", "")
    s = s.strip()
    
    return s

df_bills['text'] = df_bills["text"].apply(lambda x : normalize_text(x))
# Out:
# /var/folders/6q/sgdz8w0j6dxf5x2__gskflbc0000gn/T/ipykernel_92814/3185142679.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bills['text'] = df_bills["text"].apply(lambda x : normalize_text(x))

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")
df_bills['n_tokens'] = df_bills["text"].apply(lambda x: len(tokenizer.encode(x)))
df_bills = df_bills[df_bills.n_tokens<8192]
len(df_bills)
# Out:
# /var/folders/6q/sgdz8w0j6dxf5x2__gskflbc0000gn/T/ipykernel_92814/2516278466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bills['n_tokens'] = df_bills["text"].apply(lambda x: len(tokenizer.encode(x)))
# 20

# %%
df_bills
# Out:
#                                                  text  \
# 0   SECTION 1. SHORT TITLE. This Act may be cited ...
# 1   SECTION 1. SHORT TITLE. This Act may be cited ...
# 2   SECTION 1. RELEASE OF DOCUMENTS CAPTURED IN IR...
# 3   SECTION 1. SHORT TITLE. This Act may be cited ...
# 4   SECTION 1. SHORT TITLE. This Act may be cited ...
# 5   SECTION 1. RELIQUIDATION OF CERTAIN ENTRIES PR...
# 6   SECTION 1. SHORT TITLE. This Act may be cited ...
# 7   SECTION 1. SHORT TITLE. This Act may be cited ...
# 8   SECTION 1. SHORT TITLE. This Act may be cited ...
# 9   SECTION 1. SHORT TITLE. This Act may be cited ...
# 10  SECTION 1. SHORT TITLE. This Act may be cited ...
# 11  SECTION 1. SHORT TITLE. This Act may be cited ...
# 12  SECTION 1. FINDINGS. The Congress finds the fo...
# 13  SECTION 1. SHORT TITLE. This Act may be cited ...
# 14  SECTION 1. SHORT TITLE. This Act may be cited ...
# 15  SECTION 1. SHORT TITLE. This Act may be cited ...
# 16  SECTION 1. SHORT TITLE. This Act may be cited ...
# 17  SECTION 1. SHORT TITLE. This Act may be cited ...
# 18  SECTION 1. SHORT TITLE. This Act may be cited ...
# 19  SECTION 1. SHORT TITLE. This Act may be cited ...
#
#                                               summary  \
# 0   National Science Education Tax Incentive for B...
# 1   Small Business Expansion and Hiring Act of 201...
# 2   Requires the Director of National Intelligence...
# 3   National Cancer Act of 2003 - Amends the Publi...
# 4   Military Call-up Relief Act - Amends the Inter...
# 5   Requires the Customs Service to reliquidate ce...
# 6   Service Dogs for Veterans Act of 2009 - Direct...
# 7   Race to the Top Act of 2010 - Directs the Secr...
# 8   Troop Talent Act of 2013 - Directs the Secreta...
# 9   Taxpayer's Right to View Act of 1993 - Amends ...
# 10  Full-Service Schools Act - Establishes the Fed...
# 11  Wall Street Compensation Reform Act of 2010 - ...
# 12  Amends the Marine Mammal Protection Act of 197...
# 13  Freedom and Mobility in Consumer Banking Act -...
# 14  Education and Training for Health Act of 2017 ...
# 15  Recreational Hunting Safety and Preservation A...
# 16  Andrew Prior Act or Andrew's Law - Amends the ...
# 17  Directs the President, in coordination with de...
# 18  This measure has not been amended since it was...
# 19  Strengthening the Health Care Safety Net Act o...
#
#                                                 title  text_len  n_tokens
# 0   To amend the Internal Revenue Code of 1986 to ...      8494      1466
# 1   To amend the Internal Revenue Code of 1986 to ...      6522      1183
# 2   A bill to require the Director of National Int...      6154       937
# 3   A bill to improve data collection and dissemin...     19853      3670
# 4   A bill to amend the Internal Revenue Code of 1...      6273      1038
# 5   To provide for reliquidation of entries premat...     11691      2026
# 6   A bill to require the Secretary of Veterans Af...      5328       880
# 7   A bill to provide incentives for States and lo...     16668      2815
# 8                            Troop Talent Act of 2013     15352      2479
# 9                Taxpayer's Right to View Act of 1993      5633       947
# 10                           Full-Service Schools Act     12472      2164
# 11  A bill to amend the Internal Revenue Code of 1...     18226      2331
# 12  To amend the Marine Mammal Protection Act of 1...      5261      1192
# 13       Freedom and Mobility in Consumer Banking Act     17690      2402
# 14      Education and Training for Health Act of 2017      9037      1648
# 15  Recreational Hunting Safety and Preservation A...     13024      2209
# 16                                       Andrew's Law      5149       608
# 17                    Energy Independence Act of 2000      8007      1352
# 18              Veterans Entrepreneurship Act of 2015      7539      1393
# 19  To amend title XIX of the Social Security Act ...     18429      2678

# %%
sample_encode = tokenizer.encode(df_bills.text[0]) 
decode = tokenizer.decode_tokens_bytes(sample_encode)
decode
# Out:
# [b'SECTION',
#  b' ',
#  b'1',
#  b'.',
#  b' SHORT',
#  b' TITLE',
#  b'.',
#  b' This',
#  b' Act',
#  b' may',
#  b' be',
#  b' cited',
#  b' as',
#  b' the',
#  b' ``',
#  b'National',
#  b' Science',
#  b' Education',
#  b' Tax',
#  b' In',
#  b'cent',
#  b'ive',
#  b' for',
#  b' Businesses',
#  b' Act',
#  b' of',
#  b' ',
#  b'200',
#  b'7',
#  b"''.",
#  b' SEC',
#  b'.',
#  b' ',
#  b'2',
#  b'.',
#  b' C',
#  b'RED',
#  b'ITS',
#  b' FOR',
#  b' CERT',
#  b'AIN',
#  b' CONTRIBUT',
#  b'IONS',
#  b' BEN',
#  b'EF',
#  b'IT',
#  b'ING',
#  b' SC',
#  b'IENCE',
#  b',',
#  b' TECHNO',
#  b'LOGY',
#  b',',
#  b' ENGINE',
#  b'ERING',
#  b',',
#  b' AND',
#  b' MAT',
#  b'HE',
#  b'MAT',
#  b'ICS',
#  b' EDUC',
#  b'ATION',
#  b' AT',
#  b' THE',
#  b' ELEMENT',
#  b'ARY',
#  b' AND',
#  b' SECOND',
#  b'ARY',
#  b' SCHOOL',
#  b' LEVEL',
#  b'.',
#  b' (',
#  b'a',
#  b')',
#  b' In',
#  b' General',
#  b'.--',
#  b'Sub',
#  b'part',
#  b' D',
#  b' of',
#  b' part',
#  b' IV',
#  b' of',
#  b' sub',
#  b'chapter',
#  b' A',
#  b' of',
#  b' chapter',
#  b' ',
#  b'1',
#  b' of',
#  b' the',
#  b' Internal',
#  b' Revenue',
#  b' Code',
#  b' of',
#  b' ',
#  b'198',
#  b'6',
#  b' (',
#  b'rel',
#  b'ating',
#  b' to',
#  b' business',
#  b' related',
#  b' credits',
#  b')',
#  b' is',
#  b' amended',
#  b' by',
#  b' adding',
#  b' at',
#  b' the',
#  b' end',
#  b' the',
#  b' following',
#  b' new',
#  b' section',
#  b':',
#  b' ``',
#  b'SEC',
#  b'.',
#  b' ',
#  b'45',
#  b'O',
#  b'.',
#  b' CONTRIBUT',
#  b'IONS',
#  b' BEN',
#  b'EF',
#  b'IT',
#  b'ING',
#  b' SC',
#  b'IENCE',
#  b',',
#  b' TECHNO',
#  b'LOGY',
#  b',',
#  b' ENGINE',
#  b'ERING',
#  b',',
#  b' AND',
#  b' MAT',
#  b'HE',
#  b'MAT',
#  b'ICS',
#  b' EDUC',
#  b'ATION',
#  b' AT',
#  b' THE',
#  b' ELEMENT',
#  b'ARY',
#  b' AND',
#  b' SECOND',
#  b'ARY',
#  b' SCHOOL',
#  b' LEVEL',
#  b'.',
#  b' ``(',
#  b'a',
#  b')',
#  b' In',
#  b' General',
#  b'.--',
#  b'For',
#  b' purposes',
#  b' of',
#  b' section',
#  b' ',
#  b'38',
#  b',',
#  b' the',
#  b' elementary',
#  b' and',
#  b' secondary',
#  b' science',
#  b',',
#  b' technology',
#  b',',
#  b' engineering',
#  b',',
#  b' and',
#  b' mathematics',
#  b' (',
#  b'STEM',
#  b')',
#  b' contributions',
#  b' credit',
#  b' determined',
#  b' under',
#  b' this',
#  b' section',
#  b' for',
#  b' the',
#  b' taxable',
#  b' year',
#  b' is',
#  b' an',
#  b' amount',
#  b' equal',
#  b' to',
#  b' ',
#  b'100',
#  b' percent',
#  b' of',
#  b' the',
#  b' qualified',
#  b' STEM',
#  b' contributions',
#  b' of',
#  b' the',
#  b' taxpayer',
#  b' for',
#  b' such',
#  b' taxable',
#  b' year',
#  b'.',
#  b' ``(',
#  b'b',
#  b')',
#  b' Qualified',
#  b' STEM',
#  b' Contributions',
#  b'.--',
#  b'For',
#  b' purposes',
#  b' of',
#  b' this',
#  b' section',
#  b',',
#  b' the',
#  b' term',
#  b' `',
#  b'qualified',
#  b' STEM',
#  b' contributions',
#  b"'",
#  b' means',
#  b'--',
#  b' ``(',
#  b'1',
#  b')',
#  b' STEM',
#  b' school',
#  b' contributions',
#  b',',
#  b' ``(',
#  b'2',
#  b')',
#  b' STEM',
#  b' teacher',
#  b' extern',
#  b'ship',
#  b' expenses',
#  b',',
#  b' and',
#  b' ``(',
#  b'3',
#  b')',
#  b' STEM',
#  b' teacher',
#  b' training',
#  b' expenses',
#  b'.',
#  b' ``(',
#  b'c',
#  b')',
#  b' STEM',
#  b' School',
#  b' Contributions',
#  b'.--',
#  b'For',
#  b' purposes',
#  b' of',
#  b' this',
#  b' section',
#  b'--',
#  b' ``(',
#  b'1',
#  b')',
#  b' In',
#  b' general',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' school',
#  b' contributions',
#  b"'",
#  b' means',
#  b'--',
#  b' ``(',
#  b'A',
#  b')',
#  b' STEM',
#  b' property',
#  b' contributions',
#  b',',
#  b' and',
#  b' ``(',
#  b'B',
#  b')',
#  b' STEM',
#  b' service',
#  b' contributions',
#  b'.',
#  b' ``(',
#  b'2',
#  b')',
#  b' STEM',
#  b' property',
#  b' contributions',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' property',
#  b' contributions',
#  b"'",
#  b' means',
#  b' the',
#  b' amount',
#  b' which',
#  b' would',
#  b' (',
#  b'but',
#  b' for',
#  b' subsection',
#  b' (',
#  b'f',
#  b'))',
#  b' be',
#  b' allowed',
#  b' as',
#  b' a',
#  b' deduction',
#  b' under',
#  b' section',
#  b' ',
#  b'170',
#  b' for',
#  b' a',
#  b' charitable',
#  b' contribution',
#  b' of',
#  b' STEM',
#  b' inventory',
#  b' property',
#  b' if',
#  b'--',
#  b' ``(',
#  b'A',
#  b')',
#  b' the',
#  b' done',
#  b'e',
#  b' is',
#  b' an',
#  b' elementary',
#  b' or',
#  b' secondary',
#  b' school',
#  b' described',
#  b' in',
#  b' section',
#  b' ',
#  b'170',
#  b'(b',
#  b')(',
#  b'1',
#  b')(',
#  b'A',
#  b')(',
#  b'ii',
#  b'),',
#  b' ``(',
#  b'B',
#  b')',
#  b' substantially',
#  b' all',
#  b' of',
#  b' the',
#  b' use',
#  b' of',
#  b' the',
#  b' property',
#  b' by',
#  b' the',
#  b' done',
#  b'e',
#  b' is',
#  b' within',
#  b' the',
#  b' United',
#  b' States',
#  b' or',
#  b' within',
#  b' the',
#  b' defense',
#  b' depend',
#  b'ents',
#  b"'",
#  b' education',
#  b' system',
#  b' for',
#  b' educational',
#  b' purposes',
#  b' in',
#  b' any',
#  b' of',
#  b' the',
#  b' grades',
#  b' K',
#  b'-',
#  b'12',
#  b' that',
#  b' are',
#  b' related',
#  b' to',
#  b' the',
#  b' purpose',
#  b' or',
#  b' function',
#  b' of',
#  b' the',
#  b' done',
#  b'e',
#  b',',
#  b' ``(',
#  b'C',
#  b')',
#  b' the',
#  b' original',
#  b' use',
#  b' of',
#  b' the',
#  b' property',
#  b' begins',
#  b' with',
#  b' the',
#  b' done',
#  b'e',
#  b',',
#  b' ``(',
#  b'D',
#  b')',
#  b' the',
#  b' property',
#  b' will',
#  b' fit',
#  b' product',
#  b'ively',
#  b' into',
#  b' the',
#  b' done',
#  b'e',
#  b"'s",
#  b' education',
#  b' plan',
#  b',',
#  b' ``(',
#  b'E',
#  b')',
#  b' the',
#  b' property',
#  b' is',
#  b' not',
#  b' transferred',
#  b' by',
#  b' the',
#  b' done',
#  b'e',
#  b' in',
#  b' exchange',
#  b' for',
#  b' money',
#  b',',
#  b' other',
#  b' property',
#  b',',
#  b' or',
#  b' services',
#  b',',
#  b' except',
#  b' for',
#  b' shipping',
#  b',',
#  b' installation',
#  b' and',
#  b' transfer',
#  b' costs',
#  b',',
#  b' and',
#  b' ``(',
#  b'F',
#  b')',
#  b' the',
#  b' done',
#  b'e',
#  b"'s",
#  b' use',
#  b' and',
#  b' disposition',
#  b' of',
#  b' the',
#  b' property',
#  b' will',
#  b' be',
#  b' in',
#  b' accordance',
#  b' with',
#  b' the',
#  b' provisions',
#  b' of',
#  b' subparagraph',
#  b's',
#  b' (',
#  b'B',
#  b')',
#  b' and',
#  b' (',
#  b'E',
#  b').',
#  b' The',
#  b' determination',
#  b' of',
#  b' the',
#  b' amount',
#  b' of',
#  b' deduction',
#  b' under',
#  b' section',
#  b' ',
#  b'170',
#  b' for',
#  b' purposes',
#  b' of',
#  b' this',
#  b' paragraph',
#  b' shall',
#  b' be',
#  b' made',
#  b' as',
#  b' if',
#  b' the',
#  b' limitation',
#  b' under',
#  b' section',
#  b' ',
#  b'170',
#  b'(e',
#  b')(',
#  b'3',
#  b')(',
#  b'B',
#  b')',
#  b' applied',
#  b' to',
#  b' all',
#  b' STEM',
#  b' inventory',
#  b' property',
#  b'.',
#  b' ``(',
#  b'3',
#  b')',
#  b' STEM',
#  b' service',
#  b' contributions',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' service',
#  b' contributions',
#  b"'",
#  b' means',
#  b' the',
#  b' amount',
#  b' paid',
#  b' or',
#  b' incurred',
#  b' during',
#  b' the',
#  b' taxable',
#  b' year',
#  b' for',
#  b' STEM',
#  b' services',
#  b' provided',
#  b' in',
#  b' the',
#  b' United',
#  b' States',
#  b' or',
#  b' in',
#  b' the',
#  b' defense',
#  b' depend',
#  b'ents',
#  b"'",
#  b' education',
#  b' system',
#  b' for',
#  b' the',
#  b' exclusive',
#  b' benefit',
#  b' of',
#  b' students',
#  b' at',
#  b' an',
#  b' elementary',
#  b' or',
#  b' secondary',
#  b' school',
#  b' described',
#  b' in',
#  b' section',
#  b' ',
#  b'170',
#  b'(b',
#  b')(',
#  b'1',
#  b')(',
#  b'A',
#  b')(',
#  b'ii',
#  b')',
#  b' but',
#  b' only',
#  b' if',
#  b'--',
#  b' ``(',
#  b'A',
#  b')',
#  b' the',
#  b' taxpayer',
#  b' is',
#  b' engaged',
#  b' in',
#  b' the',
#  b' trade',
#  b' or',
#  b' business',
#  b' of',
#  b' providing',
#  b' such',
#  b' services',
#  b' on',
#  b' a',
#  b' commercial',
#  b' basis',
#  b',',
#  b' and',
#  b' ``(',
#  b'B',
#  b')',
#  b' no',
#  b' charge',
#  b' is',
#  b' imposed',
#  b' for',
#  b' providing',
#  b' such',
#  b' services',
#  b'.',
#  b' ``(',
#  b'4',
#  b')',
#  b' STEM',
#  b' inventory',
#  b' property',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' inventory',
#  b' property',
#  b"'",
#  b' means',
#  b',',
#  b' with',
#  b' respect',
#  b' to',
#  b' any',
#  b' contribution',
#  b' to',
#  b' a',
#  b' school',
#  b',',
#  b' any',
#  b' property',
#  b'--',
#  b' ``(',
#  b'A',
#  b')',
#  b' which',
#  b' is',
#  b' described',
#  b' in',
#  b' paragraph',
#  b' (',
#  b'1',
#  b')',
#  b' or',
#  b' (',
#  b'2',
#  b')',
#  b' of',
#  b' section',
#  b' ',
#  b'122',
#  b'1',
#  b'(a',
#  b')',
#  b' with',
#  b' respect',
#  b' to',
#  b' the',
#  b' donor',
#  b',',
#  b' and',
#  b' ``(',
#  b'B',
#  b')',
#  b' which',
#  b' is',
#  b' determined',
#  b' by',
#  b' the',
#  b' school',
#  b' to',
#  b' be',
#  b' needed',
#  b' by',
#  b' the',
#  b' school',
#  b' in',
#  b' providing',
#  b' education',
#  b' in',
#  b' grades',
#  b' K',
#  b'-',
#  b'12',
#  b' in',
#  b' the',
#  b' areas',
#  b' of',
#  b' science',
#  b',',
#  b' technology',
#  b',',
#  b' engineering',
#  b',',
#  b' or',
#  b' mathematics',
#  b'.',
#  b' ``(',
#  b'5',
#  b')',
#  b' STEM',
#  b' services',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' services',
#  b"'",
#  b' means',
#  b',',
#  b' with',
#  b' respect',
#  b' to',
#  b' any',
#  b' contribution',
#  b' to',
#  b' a',
#  b' school',
#  b',',
#  b' any',
#  b' service',
#  b' determined',
#  b' by',
#  b' the',
#  b' school',
#  b' to',
#  b' be',
#  b' needed',
#  b' by',
#  b' the',
#  b' school',
#  b' in',
#  b' providing',
#  b' education',
#  b' in',
#  b' grades',
#  b' K',
#  b'-',
#  b'12',
#  b' in',
#  b' the',
#  b' areas',
#  b' of',
#  b' science',
#  b',',
#  b' technology',
#  b',',
#  b' engineering',
#  b',',
#  b' or',
#  b' mathematics',
#  b',',
#  b' including',
#  b' teaching',
#  b' courses',
#  b' of',
#  b' instruction',
#  b' at',
#  b' such',
#  b' school',
#  b' in',
#  b' any',
#  b' such',
#  b' area',
#  b'.',
#  b' ``(',
#  b'6',
#  b')',
#  b' Defense',
#  b' depend',
#  b'ents',
#  b"'",
#  b' education',
#  b' system',
#  b'.--',
#  b'For',
#  b' purposes',
#  b' of',
#  b' this',
#  b' subsection',
#  b',',
#  b' the',
#  b' term',
#  b' `',
#  b'defense',
#  b' depend',
#  b'ents',
#  b"'",
#  b' education',
#  b' system',
#  b"'",
#  b' means',
#  b' the',
#  b' program',
#  b' established',
#  b' and',
#  b' operated',
#  b' under',
#  b' the',
#  b' Defense',
#  b' Depend',
#  b'ents',
#  b"'",
#  b' Education',
#  b' Act',
#  b' of',
#  b' ',
#  b'197',
#  b'8',
#  b' (',
#  b'20',
#  b' U',
#  b'.S',
#  b'.C',
#  b'.',
#  b' ',
#  b'921',
#  b' et',
#  b' seq',
#  b'.).',
#  b' ``(',
#  b'd',
#  b')',
#  b' STEM',
#  b' Teacher',
#  b' Ex',
#  b'tern',
#  b'ship',
#  b' Expenses',
#  b'.--',
#  b'For',
#  b' purposes',
#  b' of',
#  b' this',
#  b' section',
#  b'--',
#  b' ``(',
#  b'1',
#  b')',
#  b' In',
#  b' general',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' teacher',
#  b' extern',
#  b'ship',
#  b' expenses',
#  b"'",
#  b' means',
#  b' any',
#  b' amount',
#  b' paid',
#  b' or',
#  b' incurred',
#  b' to',
#  b' carry',
#  b' out',
#  b' a',
#  b' STEM',
#  b' extern',
#  b'ship',
#  b' program',
#  b' of',
#  b' the',
#  b' taxpayer',
#  b' but',
#  b' only',
#  b' to',
#  b' the',
#  b' extent',
#  b' that',
#  b' such',
#  b' amount',
#  b' is',
#  b' attributable',
#  b' to',
#  b' the',
#  b' participation',
#  b' in',
#  b' such',
#  b' program',
#  b' of',
#  b' any',
#  b' eligible',
#  b' STEM',
#  b' teacher',
#  b',',
#  b' including',
#  b' amounts',
#  b' paid',
#  b' to',
#  b' such',
#  b' a',
#  b' teacher',
#  b' as',
#  b' a',
#  b' stip',
#  b'end',
#  b' while',
#  b' participating',
#  b' in',
#  b' such',
#  b' program',
#  b'.',
#  b' ``(',
#  b'2',
#  b')',
#  b' STEM',
#  b' extern',
#  b'ship',
#  b' program',
#  b'.--',
#  b'The',
#  b' term',
#  b' `',
#  b'STEM',
#  b' extern',
#  b'ship',
#  b' program',
#  b"'",
#  b' means',
#  b' any',
#  b' program',
#  b'--',
#  b' ``(',
#  b'A',
#  b')',
#  b' established',
#  ...]

# %%
len(decode)
# Out:
# 1466

# %%
df_bills['ada_v2'] = df_bills["text"].apply(lambda x : get_embedding(x, engine = 'text-embedding-ada-002')) # engine should be set to the deployment name you chose when you deployed the text-embedding-ada-002 (Version 2) model

# %%
df_bills
# Out:
#                                                  text  \
# 0   SECTION 1. SHORT TITLE. This Act may be cited ...
# 1   SECTION 1. SHORT TITLE. This Act may be cited ...
# 2   SECTION 1. RELEASE OF DOCUMENTS CAPTURED IN IR...
# 3   SECTION 1. SHORT TITLE. This Act may be cited ...
# 4   SECTION 1. SHORT TITLE. This Act may be cited ...
# 5   SECTION 1. RELIQUIDATION OF CERTAIN ENTRIES PR...
# 6   SECTION 1. SHORT TITLE. This Act may be cited ...
# 7   SECTION 1. SHORT TITLE. This Act may be cited ...
# 8   SECTION 1. SHORT TITLE. This Act may be cited ...
# 9   SECTION 1. SHORT TITLE. This Act may be cited ...
# 10  SECTION 1. SHORT TITLE. This Act may be cited ...
# 11  SECTION 1. SHORT TITLE. This Act may be cited ...
# 12  SECTION 1. FINDINGS. The Congress finds the fo...
# 13  SECTION 1. SHORT TITLE. This Act may be cited ...
# 14  SECTION 1. SHORT TITLE. This Act may be cited ...
# 15  SECTION 1. SHORT TITLE. This Act may be cited ...
# 16  SECTION 1. SHORT TITLE. This Act may be cited ...
# 17  SECTION 1. SHORT TITLE. This Act may be cited ...
# 18  SECTION 1. SHORT TITLE. This Act may be cited ...
# 19  SECTION 1. SHORT TITLE. This Act may be cited ...
#
#                                               summary  \
# 0   National Science Education Tax Incentive for B...
# 1   Small Business Expansion and Hiring Act of 201...
# 2   Requires the Director of National Intelligence...
# 3   National Cancer Act of 2003 - Amends the Publi...
# 4   Military Call-up Relief Act - Amends the Inter...
# 5   Requires the Customs Service to reliquidate ce...
# 6   Service Dogs for Veterans Act of 2009 - Direct...
# 7   Race to the Top Act of 2010 - Directs the Secr...
# 8   Troop Talent Act of 2013 - Directs the Secreta...
# 9   Taxpayer's Right to View Act of 1993 - Amends ...
# 10  Full-Service Schools Act - Establishes the Fed...
# 11  Wall Street Compensation Reform Act of 2010 - ...
# 12  Amends the Marine Mammal Protection Act of 197...
# 13  Freedom and Mobility in Consumer Banking Act -...
# 14  Education and Training for Health Act of 2017 ...
# 15  Recreational Hunting Safety and Preservation A...
# 16  Andrew Prior Act or Andrew's Law - Amends the ...
# 17  Directs the President, in coordination with de...
# 18  This measure has not been amended since it was...
# 19  Strengthening the Health Care Safety Net Act o...
#
#                                                 title  n_tokens  \
# 0   To amend the Internal Revenue Code of 1986 to ...      1466
# 1   To amend the Internal Revenue Code of 1986 to ...      1183
# 2   A bill to require the Director of National Int...       937
# 3   A bill to improve data collection and dissemin...      3670
# 4   A bill to amend the Internal Revenue Code of 1...      1038
# 5   To provide for reliquidation of entries premat...      2026
# 6   A bill to require the Secretary of Veterans Af...       880
# 7   A bill to provide incentives for States and lo...      2815
# 8                            Troop Talent Act of 2013      2479
# 9                Taxpayer's Right to View Act of 1993       947
# 10                           Full-Service Schools Act      2164
# 11  A bill to amend the Internal Revenue Code of 1...      2331
# 12  To amend the Marine Mammal Protection Act of 1...      1192
# 13       Freedom and Mobility in Consumer Banking Act      2402
# 14      Education and Training for Health Act of 2017      1648
# 15  Recreational Hunting Safety and Preservation A...      2209
# 16                                       Andrew's Law       608
# 17                    Energy Independence Act of 2000      1352
# 18              Veterans Entrepreneurship Act of 2015      1393
# 19  To amend title XIX of the Social Security Act ...      2678
#
#                                                ada_v2
# 0   [-0.022678455337882042, -0.00799493957310915, ...
# 1   [-0.041596777737140656, -0.009042778052389622,...
# 2   [-0.0420723482966423, -0.0023871997836977243, ...
# 3   [-0.013265267945826054, -0.007186719682067633,...
# 4   [-0.03917262703180313, -0.025464843958616257, ...
# 5   [-0.016097435727715492, -0.015194901265203953,...
# 6   [-0.029804326593875885, -0.02193712815642357, ...
# 7   [-0.020575817674398422, 0.0003083075280301273,...
# 8   [-0.030029239133000374, -0.0169113427400589, 0...
# 9   [-0.018460797145962715, -0.024794351309537888,...
# 10  [-0.01014762744307518, 0.015381667762994766, -...
# 11  [-0.047416988760232925, -0.007824325934052467,...
# 12  [-0.025547074154019356, -0.0012037496780976653...
# 13  [-0.024552075192332268, 0.002101766411215067, ...
# 14  [-0.0032339368481189013, -0.000158853552420623...
# 15  [-0.022656632587313652, -0.007432988379150629,...
# 16  [-0.033216603100299835, -0.010047564283013344,...
# 17  [0.0029555223882198334, -0.024077415466308594,...
# 18  [-0.02254152111709118, -0.030212445184588432, ...
# 19  [-0.017817417159676552, -0.007099970709532499,...

# %%
# search through the reviews for a specific product
def search_docs(df, user_query, top_n=3, to_print=True):
    embedding = get_embedding(
        user_query,
        engine="text-embedding-ada-002" # engine should be set to the deployment name you chose when you deployed the text-embedding-ada-002 (Version 2) model
    )
    df["similarities"] = df.ada_v2.apply(lambda x: cosine_similarity(x, embedding))

    res = (
        df.sort_values("similarities", ascending=False)
        .head(top_n)
    )
    if to_print:
        display(res)
    return res


res = search_docs(df_bills, "Can I get information on cable company tax revenue?", top_n=4)
# Out:
#                                                  text  \
# 9   SECTION 1. SHORT TITLE. This Act may be cited ...
# 1   SECTION 1. SHORT TITLE. This Act may be cited ...
# 11  SECTION 1. SHORT TITLE. This Act may be cited ...
# 19  SECTION 1. SHORT TITLE. This Act may be cited ...
#
#                                               summary  \
# 9   Taxpayer's Right to View Act of 1993 - Amends ...
# 1   Small Business Expansion and Hiring Act of 201...
# 11  Wall Street Compensation Reform Act of 2010 - ...
# 19  Strengthening the Health Care Safety Net Act o...
#
#                                                 title  n_tokens  \
# 9                Taxpayer's Right to View Act of 1993       947
# 1   To amend the Internal Revenue Code of 1986 to ...      1183
# 11  A bill to amend the Internal Revenue Code of 1...      2331
# 19  To amend title XIX of the Social Security Act ...      2678
#
#                                                ada_v2  similarities
# 9   [-0.018460797145962715, -0.024794351309537888,...      0.819775
# 1   [-0.041596777737140656, -0.009042778052389622,...      0.734921
# 11  [-0.047416988760232925, -0.007824325934052467,...      0.734551
# 19  [-0.017817417159676552, -0.007099970709532499,...      0.733241

# %%
res["summary"][9]
# Out:
# "Taxpayer's Right to View Act of 1993 - Amends the Communications Act of 1934 to prohibit a cable operator from assessing separate charges for any video programming of a sporting, theatrical, or other entertainment event if that event is performed at a facility constructed, renovated, or maintained with tax revenues or by an organization that receives public financial support. Authorizes the Federal Communications Commission and local franchising authorities to make determinations concerning the applicability of such prohibition. Sets forth conditions under which a facility is considered to have been constructed, maintained, or renovated with tax revenues. Considers events performed by nonprofit or public organizations that receive tax subsidies to be subject to this Act if the event is sponsored by, or includes the participation of a team that is part of, a tax exempt organization."
